# %% [markdown]
# <a href="https://colab.research.google.com/github/tsaltsaeca-droid/KAL/blob/main/250411100142_Tugas-Reflekdi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

# Titik awal (persegi dekat sumbu X)
square_init = np.array([
    [1,1],
    [3,1],
    [3,2],
    [1,2]
])

dx = 0
dy = 1
steps = 6

fig, ax = plt.subplots(figsize=(6,6))

# Grid & sumbu (lebih simetris)
ax.set_xlim(0, 6)
ax.set_ylim(-8, 8)
ax.set_xticks(range(0,7))
ax.set_yticks(range(-8,9))
ax.grid(True)

ax.axhline(0, linewidth=1.5)  # sumbu X (cermin)
ax.axvline(0, linewidth=1)

original_plot, = ax.plot([], [], 'bo-', label='Objek Asli')
reflection_plot, = ax.plot([], [], 'ro--', label='Refleksi')

ax.legend()
ax.set_title("Refleksi Sumbu X (Menjauh dari Cermin)")

texts = []

def update(frame):
    nonlocal_square = square_init + np.array([dx, dy]) * frame

    # refleksi
    reflected = nonlocal_square.copy()
    reflected[:,1] = -reflected[:,1]

    # tutup bentuk
    sq = np.vstack([nonlocal_square, nonlocal_square[0]])
    ref = np.vstack([reflected, reflected[0]])

    # update plot
    original_plot.set_data(sq[:,0], sq[:,1])
    reflection_plot.set_data(ref[:,0], ref[:,1])

    # hapus label lama
    for t in texts:
        t.remove()
    texts.clear()

    # label titik
    labels = ['A','B','C','D']
    for i, label in enumerate(labels):
        x, y = nonlocal_square[i]
        xr, yr = reflected[i]

        texts.append(ax.text(x+0.1, y+0.1, f"{label}({x},{y})",
                             color='blue', fontsize=9))

        texts.append(ax.text(x+0.1, yr-0.8, f"{label}'({xr},{yr})",
                             color='red', fontsize=9))

    return original_plot, reflection_plot, *texts

ani = FuncAnimation(fig, update, frames=steps, interval=800)

HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %% [markdown]
# ## Perhitungan Refleksi Sumbu X dengan Perkalian Matriks
#
# Diketahui:
# $$
# A(1,1),\quad B(3,1),\quad C(3,2),\quad D(1,2)
# $$
#
# Matriks refleksi sumbu X:
# $$
# \begin{bmatrix}
# 1 & 0 \\
# 0 & -1
# \end{bmatrix}
# $$
#
# ---
#
# # 🔹 Contoh Frame t = 2
#
# ## 1. Translasi (y + 2)
#
# $$
# A(1,1) \rightarrow (1,3)
# $$
# $$
# B(3,1) \rightarrow (3,3)
# $$
# $$
# C(3,2) \rightarrow (3,4)
# $$
# $$
# D(1,2) \rightarrow (1,4)
# $$
#
# ---
#
# ## 2. Refleksi dengan Perkalian Matriks
#
# ### Titik A
# $$
# A =
# \begin{bmatrix}
# 1 \\
# 3
# \end{bmatrix}
# $$
#
# $$
# \begin{bmatrix}
# 1 & 0 \\
# 0 & -1
# \end{bmatrix}
# \begin{bmatrix}
# 1 \\
# 3
# \end{bmatrix}
# =
# \begin{bmatrix}
# (1)(1) + (0)(3) \\
# (0)(1) + (-1)(3)
# \end{bmatrix}
# =
# \begin{bmatrix}
# 1 \\
# -3
# \end{bmatrix}
# $$
#
# $$
# A' = (1,-3)
# $$
#
# ---
#
# ### Titik B
# $$
# \begin{bmatrix}
# 3 \\
# 3
# \end{bmatrix}
# $$
#
# $$
# \begin{bmatrix}
# 1 & 0 \\
# 0 & -1
# \end{bmatrix}
# \begin{bmatrix}
# 3 \\
# 3
# \end{bmatrix}
# =
# \begin{bmatrix}
# (1)(3) + (0)(3) \\
# (0)(3) + (-1)(3)
# \end{bmatrix}
# =
# \begin{bmatrix}
# 3 \\
# -3
# \end{bmatrix}
# $$
#
# $$
# B' = (3,-3)
# $$
#
# ---
#
# ### Titik C
# $$
# \begin{bmatrix}
# 3 \\
# 4
# \end{bmatrix}
# $$
#
# $$
# \begin{bmatrix}
# 1 & 0 \\
# 0 & -1
# \end{bmatrix}
# \begin{bmatrix}
# 3 \\
# 4
# \end{bmatrix}
# =
# \begin{bmatrix}
# (1)(3) + (0)(4) \\
# (0)(3) + (-1)(4)
# \end{bmatrix}
# =
# \begin{bmatrix}
# 3 \\
# -4
# \end{bmatrix}
# $$
#
# $$
# C' = (3,-4)
# $$
#
# ---
#
# ### Titik D
# $$
# \begin{bmatrix}
# 1 \\
# 4
# \end{bmatrix}
# $$
#
# $$
# \begin{bmatrix}
# 1 & 0 \\
# 0 & -1
# \end{bmatrix}
# \begin{bmatrix}
# 1 \\
# 4
# \end{bmatrix}
# =
# \begin{bmatrix}
# (1)(1) + (0)(4) \\
# (0)(1) + (-1)(4)
# \end{bmatrix}
# =
# \begin{bmatrix}
# 1 \\
# -4
# \end{bmatrix}
# $$
#
# $$
# D' = (1,-4)
# $$
