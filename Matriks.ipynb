# %% [markdown]
# $$
# A =
# \begin{bmatrix}
# 3 & 2 & 1 & 5\\
# 2 & 1 & 2 & 3\\
# 1 & 2 & 4 & 5
# \end{bmatrix}
# $$
#
# $$
# B =
# \begin{bmatrix}
# 1 & 3 & 2 & 5\\
# 5 & 4 & 2 & 3\\
# 2 & 1 & 3 & 5
# \end{bmatrix}
# $$
#
# $$
# B =
# \begin{bmatrix}
# 1 & 3 & 2 & 5\\
# 5 & 4 & 2 & 3\\
# 2 & 1 & 3 & 5
# \end{bmatrix}
# $$
