# %% [markdown]
# Perintah:
#
# Kerjaka soal berikut dengan dan hasilnya di tulis di webstatis dan dikumpulkan di webstatis github
# Dijelaskan dengan proses-proses untuk mendapatkanya sesuai dengan rumus
#
# SOAL.
#
# **A. Hitunglah determinan matrik berikut dengan menggunakan rumus expansi baris**

# %% [markdown]
# $$\sum_{k=1}^n (-1)^{i+k} a_{ik} M_{ik}$$
# dengan $M_{ik}$ adalah minior dari matrik A dan
# $$M_{ij} = \det A_{ij}$$

# %% [markdown]
# $A_{ij}$ adalah submatrik dengan menghapus baris i dan kolom kolom j dari matrix $A_{mxn}$ dengan $1 \le i, j \le n$

# %% [markdown]
# 1. $$A = \begin{bmatrix} -7 & -5 \\ 1 & 4 \end{bmatrix}$$

# %% [markdown]
# 2. $$A = \begin{bmatrix} 0 & 2 & -3 \\ 1 & -2 & -1 \\ 0 & 0 & 1 \end{bmatrix}$$

# %% [markdown]
# 3. $$A = \begin{bmatrix} 1 & -3 & 1 & 1 \\ -3 & 1 & 1 & 1 \\ 1 & 1 & -3 & 1 \\ 1 & 1 & 1 & -3 \end{bmatrix}.$$

# %% [markdown]
# JAWAB :
# 1. $$det A = (-1)^{1+1} a_{11} \det M_{11} + (-1)^{1+2} a_{12} \det M_{12}$$
# $$1(-7)(4) - 1(-5)(1)$$
# $$(-28) + 5 = -23$$

# %% [markdown]
# 2. $$det A = (-1)^{1+1} a_{11} \det M_{11} + (-1)^{1+2} a_{12} \det M_{12} + (-1)^{1+3} a_{13} \det M_{13}$$
# $$1(0)\begin{bmatrix} -2 & -1 \\ 0 & 1 \end{bmatrix} - 1(2)\begin{bmatrix} 1 & -1 \\ 0 & 1 \end{bmatrix} + 1(-3)\begin{bmatrix} 1 & -2 \\ 0 & 0 \end{bmatrix}$$
# $$(0((-2)×(-1)-(-1)×0)) - (2(1×1-(-1)×0)) + (-3(1×0-(-2)×0))$$
# $$0 - 2 + 0 = -2$$

# %% [markdown]
# 3. $$\det(A) = a_{11}(-1)^{1+1}\det(M_{11}) + a_{12}(-1)^{1+2}\det(M_{12}) + a_{13}(-1)^{1+3}\det(M_{13}) + a_{14}(-1)^{1+4}\det(M_{14})$$
# $$1(1)M_{12} =\begin{bmatrix}1 & 1 & 1 \\1 & -3 & 1 \\1 & 1 & -3\end{bmatrix} - 1(-3)\begin{bmatrix}-3 & 1 & 1 \\1 & -3 & 1 \\1 & 1 & -3\end{bmatrix} + 1(1)\begin{bmatrix}-3 & 1 & 1 \\1 & 1 & 1 \\1 & 1 & -3\end{bmatrix} - 1(1)\begin{bmatrix}-3 & 1 & 1 \\1 & 1 & -3 \\1 & 1 & 1\end{bmatrix} $$
# $$\det(A) = 16 + 3(−16) + 16 − (−16) = 16 − 48 + 16 + 16 = 0$$

# %% [markdown]
# **B. Gunakan rumus matriks adjoin untuk menghitung invers dari matriks berikut dengan rumus**
# $$(\operatorname{adj} A)_{ij} = (-1)^{i+j} M_{ji}$$
# dan
# $$A^{-1} = \frac{1}{\det A} \operatorname{adj} A.$$

# %% [markdown]
# 1. $$A = \begin{bmatrix} -7 & -5 \\ 1 & 4 \end{bmatrix}$$

# %% [markdown]
# 2. $$A = \begin{bmatrix} 0 & 2 & -3 \\ 1 & -2 & -1 \\ 0 & 0 & 1 \end{bmatrix}$$

# %% [markdown]
# 3. $$A = \begin{bmatrix} 1 & -3 & 1 & 1 \\ -3 & 1 & 1 & 1 \\ 1 & 1 & -3 & 1 \\ 1 & 1 & 1 & -3 \end{bmatrix}.$$

# %% [markdown]
# JAWAB :
#
#
# 1.
# $(adj A)_{11} = (-1)^{1+1} M_{11} = (-1)^{2} (4) = 4$
#
# $(adj A)_{12} = (-1)^{1+2} M_{21} = (-1)^{3} (-5) = 5$
#
# $(adj A)_{21} = (-1)^{2+1} M_{12} = (-1)^{3} (1) = -1$
#
# $(adj A)_{22} = (-1)^{2+2} M_{22} = (-1)^{4} (-7) = -7$
#
# $$adj A = \begin{bmatrix} 4 & 5 \\ -1 & -7 \end{bmatrix}$$
# $$A^{-1} = \frac{1}{-23} \begin{bmatrix} 4 & 5 \\ -1 & -7 \end{bmatrix} = \begin{bmatrix} \frac{4}{-23} & \frac{5}{-23} \\ \frac{-1}{-23} & \frac{-7}{-23} \end{bmatrix}$$

# %% [markdown]
# 2.
# $(adj A)_{11} = (-1)^{1+1} M_{11} = (-1)^{2} \begin{bmatrix} -2 & -1 \\ 0 & 1 \end{bmatrix} = -2$
#
# $(adj A)_{12} = (-1)^{1+2} M_{21} = (-1)^{3} \begin{bmatrix} 2 & -3 \\ 0 & 1 \end{bmatrix} = -2$
#
# $(adj A)_{13} = (-1)^{1+3} M_{31} = (-1)^{4} \begin{bmatrix} 2 & -3 \\ -2 & 1 \end{bmatrix} = 4$
#
# $(adj A)_{21} = (-1)^{2+1} M_{12} = (-1)^{3} \begin{bmatrix} 1 & -1 \\ 0 & 1 \end{bmatrix} = -1$
#
# $(adj A)_{22} = (-1)^{2+2} M_{22} = (-1)^{4} \begin{bmatrix} 0 & -3 \\ 0 & 1 \end{bmatrix} = 0$
#
# $(adj A)_{23} = (-1)^{2+3} M_{32} = (-1)^{5} \begin{bmatrix} 0 & -3 \\ 1 & -1 \end{bmatrix} = 3$
#
# $(adj A)_{31} = (-1)^{3+1} M_{13} = (-1)^{4} \begin{bmatrix} 1 & -2 \\ 0 & 0 \end{bmatrix} = 0$
#
# $(adj A)_{32} = (-1)^{3+2} M_{23} = (-1)^{5} \begin{bmatrix} 0 & 2 \\ 0 & 0 \end{bmatrix} = 0$
#
# $(adj A)_{33} = (-1)^{3+3} M_{33} = (-1)^{6} \begin{bmatrix} 0 & 2 \\ 1 & -2 \end{bmatrix} = 2$
#
# $$adj A = \begin{bmatrix} -2 & -2 & 4 \\ -1 & 0 & 3 \\ 0 & 0 & 2 \end{bmatrix}$$
#
# $$A^{-1} = \frac{1}{-2}  \begin{bmatrix} -2 & -2 & 4 \\ -1 & 0 & 3 \\ 0 & 0 & 2 \end{bmatrix} = \begin{bmatrix} 1 & 1 & -2 \\ \frac{1}{2} & 0 & \frac {-3}{2} \\ 0 & 0 & -1 \end{bmatrix}$$

# %% [markdown]
# 3. $$ \text{adj}(A) = \begin{bmatrix} 16 & 16 & 16 & 16 \\ 16 & 16 & 16 & 16 \\ 16 & 16 & 16 & 16 \\ 16 & 16 & 16 & 16 \end{bmatrix}$$
# $$
# \det(A) = 0 \Rightarrow A \text{ adalah matriks singular}
# $$
#
# $$
# \Rightarrow A^{-1} \text{ tidak ada}
# $$
